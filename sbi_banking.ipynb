# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-openai
# !pip install faiss-cpu
# !pip install sentence-transformers
# !pip install pypdf
# !pip install streamlit
# !pip install python-dotenv
# Out:
# Collecting langchain
#   Downloading langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in d:\anaconda\lib\site-packages (from langchain) (1.5.0)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.9-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in d:\anaconda\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in d:\anaconda\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\anaconda\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: anyio>=3.5.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.24.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.5.0)
# Downloading langchain-1.3.14-py3-none-any.whl (139 kB)
# Downloading langgraph-1.2.9-py3-none-any.whl (247 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Installing collected packages: websockets, ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 16.1.1
#
#     Uninstalling websockets-16.1.1:
#
#       Successfully uninstalled websockets-16.1.1
#
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ---------------------------------------- 0/7 [websockets]
#    ----- ---------------------------------- 1/7 [ormsgpack]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------- ---------------------------- 2/7 [langgraph-sdk]
#    ----------------- ---------------------- 3/7 [langgraph-checkpoint]
#    ----------------- ---------------------- 3/7 [langgraph-checkpoint]
#    ---------------------- ----------------- 4/7 [langgraph-prebuilt]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------- ----------- 5/7 [langgraph]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------- ----- 6/7 [langchain]
#    ---------------------------------------- 7/7 [langchain]
#
# Successfully installed langchain-1.3.14 langgraph-1.2.9 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 ormsgpack-1.12.2 websockets-15.0.1
# Requirement already satisfied: langchain-community in d:\anaconda\lib\site-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\anaconda\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\anaconda\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in d:\anaconda\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from langchain-community) (1.5.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in d:\anaconda\lib\site-packages (from langchain-community) (0.10.10)
# Requirement already satisfied: numpy>=2.1.0 in d:\anaconda\lib\site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\anaconda\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in d:\anaconda\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\anaconda\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in d:\anaconda\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\anaconda\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in d:\anaconda\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Collecting langchain-openai
#   Downloading langchain_openai-1.4.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.0 in d:\anaconda\lib\site-packages (from langchain-openai) (1.5.0)
# Collecting openai<3.0.0,>=2.45.0 (from langchain-openai)
#   Downloading openai-2.47.0-py3-none-any.whl.metadata (36 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.13.0-cp313-cp313-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.0->langchain-openai) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.24.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.16.0)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.45.0->langchain-openai)
#   Downloading jiter-0.16.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: tqdm>4 in d:\anaconda\lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.0->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.5.0->langchain-openai) (0.4.2)
# Requirement already satisfied: regex in d:\anaconda\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.0->langchain-openai) (2.5.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.4.0-py3-none-any.whl (121 kB)
# Downloading openai-2.47.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 3.1 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.9 MB/s  0:00:00
# Downloading jiter-0.16.0-cp313-cp313-win_amd64.whl (196 kB)
# Downloading tiktoken-0.13.0-cp313-cp313-win_amd64.whl (874 kB)
#    ---------------------------------------- 0.0/874.8 kB ? eta -:--:--
#    ----------------------------------- ---- 786.4/874.8 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 874.8/874.8 kB 3.5 MB/s  0:00:00
# Installing collected packages: jiter, tiktoken, openai, langchain-openai
#
#    ---------- ----------------------------- 1/4 [tiktoken]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    -------------------- ------------------- 2/4 [openai]
#    ------------------------------ --------- 3/4 [langchain-openai]
#    ------------------------------ --------- 3/4 [langchain-openai]
#    ------------------------------ --------- 3/4 [langchain-openai]
#    ---------------------------------------- 4/4 [langchain-openai]
#
# Successfully installed jiter-0.16.0 langchain-openai-1.4.0 openai-2.47.0 tiktoken-0.13.0
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp313-cp313-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.25 in d:\anaconda\lib\site-packages (from faiss-cpu) (2.3.5)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.14.3-cp313-cp313-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/16.2 MB 20.3 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/16.2 MB 20.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.8/16.2 MB 20.6 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 19.3 MB/s  0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.14.3
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.24.0-py3-none-any.whl.metadata (16 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.13.0-cp313-cp313-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.20.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in d:\anaconda\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached regex-2026.7.19-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in d:\anaconda\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: filelock>=3.10.0 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.10.0)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading hf_xet-1.5.2-cp38-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools>=77.0.3 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\anaconda\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading sentence_transformers-5.6.0-py3-none-any.whl (596 kB)
#    ---------------------------------------- 0.0/596.4 kB ? eta -:--:--
#    ---------------------------------------- 596.4/596.4 kB 13.1 MB/s  0:00:00
# Downloading transformers-5.14.1-py3-none-any.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------- ----------------- 6.6/11.6 MB 30.5 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.6 MB 29.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 26.4 MB/s  0:00:00
# Downloading huggingface_hub-1.24.0-py3-none-any.whl (771 kB)
#    ---------------------------------------- 0.0/771.9 kB ? eta -:--:--
#    ---------------------------------------- 771.9/771.9 kB 14.0 MB/s  0:00:00
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Downloading hf_xet-1.5.2-cp38-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 30.4 MB/s  0:00:00
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached regex-2026.7.19-cp313-cp313-win_amd64.whl (277 kB)
# Using cached safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Downloading torch-2.13.0-cp313-cp313-win_amd64.whl (122.1 MB)
#    ---------------------------------------- 0.0/122.1 MB ? eta -:--:--
#    - -------------------------------------- 5.8/122.1 MB 29.6 MB/s eta 0:00:04
#    --- ------------------------------------ 11.5/122.1 MB 28.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 17.0/122.1 MB 27.7 MB/s eta 0:00:04
#    ------- -------------------------------- 22.8/122.1 MB 27.5 MB/s eta 0:00:04
#    --------- ------------------------------ 28.8/122.1 MB 28.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 35.4/122.1 MB 28.5 MB/s eta 0:00:04
#    ------------- -------------------------- 41.9/122.1 MB 29.0 MB/s eta 0:00:03
#    --------------- ------------------------ 47.7/122.1 MB 28.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 53.7/122.1 MB 28.9 MB/s eta 0:00:03
#    ------------------- -------------------- 60.0/122.1 MB 29.0 MB/s eta 0:00:03
#    --------------------- ------------------ 65.3/122.1 MB 28.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 71.6/122.1 MB 28.7 MB/s eta 0:00:02
#    ------------------------- -------------- 77.6/122.1 MB 28.8 MB/s eta 0:00:02
#    --------------------------- ------------ 83.1/122.1 MB 28.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 88.6/122.1 MB 28.4 MB/s eta 0:00:02
#    ------------------------------ --------- 93.8/122.1 MB 28.1 MB/s eta 0:00:02
#    -------------------------------- ------- 98.6/122.1 MB 27.8 MB/s eta 0:00:01
#    -------------------------------- ------ 102.5/122.1 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------- ---- 107.2/122.1 MB 27.0 MB/s eta 0:00:01
#    ----------------------------------- --- 110.6/122.1 MB 26.5 MB/s eta 0:00:01
#    ------------------------------------ -- 115.1/122.1 MB 26.4 MB/s eta 0:00:01
#    --------------------------------------  119.0/122.1 MB 26.1 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.1 MB 25.9 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.1 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------- 122.1/122.1 MB 24.3 MB/s  0:00:05
# Installing collected packages: safetensors, regex, hf-xet, click, torch, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ---------------------------------------- 0/9 [safetensors]
#   Attempting uninstall: regex
#    ---------------------------------------- 0/9 [safetensors]
#     Found existing installation: regex 2025.9.1
#    ---------------------------------------- 0/9 [safetensors]
#     Uninstalling regex-2025.9.1:
#    ---------------------------------------- 0/9 [safetensors]
#       Successfully uninstalled regex-2025.9.1
#    ---------------------------------------- 0/9 [safetensors]
#    ---- ----------------------------------- 1/9 [regex]
#    -------- ------------------------------- 2/9 [hf-xet]
#   Attempting uninstall: click
#    -------- ------------------------------- 2/9 [hf-xet]
#     Found existing installation: click 8.2.1
#    -------- ------------------------------- 2/9 [hf-xet]
#     Uninstalling click-8.2.1:
#    -------- ------------------------------- 2/9 [hf-xet]
#       Successfully uninstalled click-8.2.1
#    -------- ------------------------------- 2/9 [hf-xet]
#    ------------- -------------------------- 3/9 [click]
#    ------------- -------------------------- 3/9 [click]
#    ------------- -------------------------- 3/9 [click]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
#    ----------------- ---------------------- 4/9 [torch]
# ...
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ------------------------------- -------- 7/9 [transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ----------------------------------- ---- 8/9 [sentence-transformers]
#    ---------------------------------------- 9/9 [sentence-transformers]
#
# Successfully installed click-8.4.2 hf-xet-1.5.2 huggingface-hub-1.24.0 regex-2026.7.19 safetensors-0.8.0 sentence-transformers-5.6.0 tokenizers-0.22.2 torch-2.13.0 transformers-5.14.1
# Collecting pypdf
#   Downloading pypdf-6.14.2-py3-none-any.whl.metadata (7.2 kB)
# Downloading pypdf-6.14.2-py3-none-any.whl (349 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.14.2
# Requirement already satisfied: streamlit in d:\anaconda\lib\site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in d:\anaconda\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in d:\anaconda\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in d:\anaconda\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in d:\anaconda\lib\site-packages (from streamlit) (8.4.2)
# Requirement already satisfied: numpy<3,>=1.23 in d:\anaconda\lib\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in d:\anaconda\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in d:\anaconda\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in d:\anaconda\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in d:\anaconda\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in d:\anaconda\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in d:\anaconda\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in d:\anaconda\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in d:\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in d:\anaconda\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in d:\anaconda\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in d:\anaconda\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in d:\anaconda\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in d:\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\anaconda\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.6.17)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: python-dotenv in d:\anaconda\lib\site-packages (1.1.0)

# %%
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq

# ============================
# SET YOUR GROQ API KEY
# ============================

os.environ["GROQ_API_KEY"] = "gsk_your_actual_groq_key"

# Check API Key

key = os.getenv("GROQ_API_KEY")

print("Key Exists:", key is not None)
print("Prefix:", key[:8])
print("Length:", len(key))

# ==============================
# STEP 2: Load PDF
# ==============================
pdf_path =r"C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf"

loader = PyPDFLoader(pdf_path)
documents = loader.load()

print(f"Total Pages: {len(documents)}")

# ==============================
# STEP 3: Split into Chunks
# ==============================
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(f"Total Chunks: {len(chunks)}")

# ==============================
# STEP 4: Create Embeddings
# ==============================
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# ==============================
# STEP 5: Create FAISS Database
# ==============================
vector_db = FAISS.from_documents(
    chunks,
    embedding_model
)

print("Vector Database Created Successfully")

# ============================
# LOAD LLM
# ============================

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)
# ==============================
# STEP 7: Ask User Question
# ==============================
question = input("\nAsk your banking question: ")

# ==============================
# STEP 8: Retrieve Relevant Chunks
# ==============================
docs = vector_db.similarity_search(
    question,
    k=3
)

# ==============================
# STEP 9: Build Context
# ==============================
context = ""

for doc in docs:
    context += doc.page_content
    context += "\n\n"

# ==============================
# STEP 10: Prompt
# ==============================
prompt = f"""
You are a banking assistant.

Answer ONLY from the given context.

If the answer is not available in the context,
reply:

"I couldn't find that information in the uploaded banking documents."

Context:
{context}

Question:
{question}
"""

# ==============================
# STEP 11: Generate Answer
# ==============================
response = llm.invoke(prompt)

# ==============================
# STEP 12: Print Answer
# ==============================
print("\n========== ANSWER ==========\n")
print(response.content)

# ==============================
# STEP 13: Show Source Pages
# ==============================
print("\n========== SOURCES ==========\n")

for i, doc in enumerate(docs, start=1):
    print(
        f"Source {i}: "
        f"{doc.metadata.get('source')} | "
        f"Page: {doc.metadata.get('page') + 1}"
    )
# Out:
# Key exists: True
# Prefix: groq_api
# Length: 12
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[16], line 26
#      20 print("Length:", len(key))
#      22 llm = ChatGroq(
#      23     model="llama-3.1-8b-instant"
#      24 )
# ---> 26 response = llm.invoke("Hello")
#      28 print(response.content)
#      30 # ==============================
#      31 # STEP 2: Load PDF
#      32 # ==============================
#
# File d:\Anaconda\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\Anaconda\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Anaconda\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\Anaconda\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Anaconda\Lib\site-packages\langchain_groq\chat_models.py:627, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     622 message_dicts, params = self._create_message_dicts(messages, stop)
#     623 params = {
#     624     **params,
#     625     **kwargs,
#     626 }
# --> 627 response = self.client.create(messages=message_dicts, **params)
#     628 return self._create_chat_result(response, params)
#
# File d:\Anaconda\Lib\site-packages\groq\resources\chat\completions.py:461, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     241 def create(
#     242     self,
#     243     *,
#    (...)    300     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     301 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     302     """
#     303     Creates a model response for the given chat conversation.
#     304
#    (...)    459       timeout: Override the client-level default timeout for this request, in seconds
#     460     """
# --> 461     return self._post(
#     462         "/openai/v1/chat/completions",
#     463         body=maybe_transform(
#     464             {
#     465                 "messages": messages,
#     466                 "model": model,
#     467                 "citation_options": citation_options,
#     468                 "compound_custom": compound_custom,
#     469                 "disable_tool_validation": disable_tool_validation,
#     470                 "documents": documents,
#     471                 "exclude_domains": exclude_domains,
#     472                 "frequency_penalty": frequency_penalty,
#     473                 "function_call": function_call,
#     474                 "functions": functions,
#     475                 "include_domains": include_domains,
#     476                 "include_reasoning": include_reasoning,
#     477                 "logit_bias": logit_bias,
#     478                 "logprobs": logprobs,
#     479                 "max_completion_tokens": max_completion_tokens,
#     480                 "max_tokens": max_tokens,
#     481                 "metadata": metadata,
#     482                 "n": n,
#     483                 "parallel_tool_calls": parallel_tool_calls,
#     484                 "presence_penalty": presence_penalty,
#     485                 "reasoning_effort": reasoning_effort,
#     486                 "reasoning_format": reasoning_format,
#     487                 "response_format": response_format,
#     488                 "search_settings": search_settings,
#     489                 "seed": seed,
#     490                 "service_tier": service_tier,
#     491                 "stop": stop,
#     492                 "store": store,
#     493                 "stream": stream,
#     494                 "temperature": temperature,
#     495                 "tool_choice": tool_choice,
#     496                 "tools": tools,
#     497                 "top_logprobs": top_logprobs,
#     498                 "top_p": top_p,
#     499                 "user": user,
#     500             },
#     501             completion_create_params.CompletionCreateParams,
#     502         ),
#     503         options=make_request_options(
#     504             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     505         ),
#     506         cast_to=ChatCompletion,
#     507         stream=stream or False,
#     508         stream_cls=Stream[ChatCompletionChunk],
#     509     )
#
# File d:\Anaconda\Lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Anaconda\Lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}

# %%
# !pip install langchain.text_splitter
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain.text_splitter (from versions: none)
# ERROR: No matching distribution found for langchain.text_splitter

# %%
# !pip install langchain-huggingface
# !pip install langchain-text-splitters
# Out:
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in d:\anaconda\lib\site-packages (from langchain-huggingface) (1.24.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in d:\anaconda\lib\site-packages (from langchain-huggingface) (1.5.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in d:\anaconda\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.10.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.10.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.12.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.0.0)
# Requirement already satisfied: distro>=1.7.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.5.0)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-1.2.2
# Requirement already satisfied: langchain-text-splitters in d:\anaconda\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in d:\anaconda\lib\site-packages (from langchain-text-splitters) (1.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: anyio>=3.5.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.24.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from langchain_groq) (1.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.4)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.32.5)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.5.0)
# Downloading langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain_groq
#
#   Attempting uninstall: groq
#
#     Found existing installation: groq 1.5.0
#
#     Uninstalling groq-1.5.0:
#
#       Successfully uninstalled groq-1.5.0
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    -------------------- ------------------- 1/2 [langchain_groq]
#    ---------------------------------------- 2/2 [langchain_groq]
#
# Successfully installed groq-0.37.1 langchain_groq-1.1.3

# %%
# !pip install -U langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in d:\anaconda\lib\site-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in d:\anaconda\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in d:\anaconda\lib\site-packages (from langchain-groq) (1.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.4)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\anaconda\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.10.10)
# Requirement already satisfied: packaging>=23.2.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\anaconda\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\anaconda\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.32.5)
# Requirement already satisfied: websockets>=15.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\anaconda\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.5.0)

# %%
import os

key = os.environ.get("GROQ_API_KEY")

print("Key exists:", key is not None)

if key:
    print("Starts with:", key[:8])
    print("Length:", len(key))
# Out:
# Key exists: True
# Starts with: YOUR_NEW
# Length: 21

# %%
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq

# =========================================
# STEP 1: SET GROQ API KEY
# =========================================
from dotenv import load_dotenv
import os

load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# =========================================
# STEP 2: LOAD PDF
# =========================================

pdf_path = r"C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf"

loader = PyPDFLoader(pdf_path)
documents = loader.load()

print(f"PDF Loaded Successfully")
print(f"Total Pages: {len(documents)}")

# =========================================
# STEP 3: SPLIT DOCUMENT
# =========================================

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(f"Total Chunks: {len(chunks)}")

# =========================================
# STEP 4: CREATE EMBEDDINGS
# =========================================

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# =========================================
# STEP 5: CREATE FAISS VECTOR DATABASE
# =========================================

vector_db = FAISS.from_documents(
    chunks,
    embedding_model
)

print("Vector Database Created Successfully")

# =========================================
# STEP 6: LOAD GROQ MODEL
# =========================================

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0
)

print("Groq Model Loaded Successfully")

# =========================================
# STEP 7: ASK QUESTION
# =========================================

while True:

    question = input("\nAsk your banking question (type 'exit' to quit): ")

    if question.lower() == "exit":
        print("Thank you!")
        break

    # Retrieve Top 3 Similar Chunks
    docs = vector_db.similarity_search(
        question,
        k=3
    )

    # Build Context
    context = "\n\n".join(doc.page_content for doc in docs)

    # Prompt
    prompt = f"""
You are an SBI Banking AI Assistant.

Answer ONLY using the information provided in the context.

If the answer is not available in the context, reply exactly:

I couldn't find that information in the uploaded banking documents.

Context:
{context}

Question:
{question}

Answer:
"""

    # Generate Answer
    response = llm.invoke(prompt)

    print("\n" + "="*60)
    print("ANSWER")
    print("="*60)
    print(response.content)

    print("\n" + "="*60)
    print("SOURCE PAGES")
    print("="*60)

    for i, doc in enumerate(docs, start=1):

        source = doc.metadata.get("source", "Unknown")

        page = doc.metadata.get("page", 0) + 1

        print(f"{i}. {source} | Page {page}")

    print("\n" + "-"*70)
# Out:
# PDF Loaded Successfully
# Total Pages: 70
# Total Chunks: 182
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Vector Database Created Successfully
# Groq Model Loaded Successfully
#
# ============================================================
# ANSWER
# ============================================================
# I couldn't find that information in the uploaded banking documents.
#
# ============================================================
# SOURCE PAGES
# ============================================================
# 1. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 3
# 2. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 3
# 3. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 36
#
# ----------------------------------------------------------------------
#
# ============================================================
# ANSWER
# ============================================================
# Term Deposit is a type of deposit product offered by SBI, where a customer deposits a certain amount for a fixed period, ranging from 7 days to 10 years. Interest is paid at monthly/quarterly/half-yearly/yearly intervals.
#
# ============================================================
# SOURCE PAGES
# ============================================================
# 1. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 19
# 2. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 10
# 3. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 9
#
# ----------------------------------------------------------------------
#
# ============================================================
# ANSWER
# ============================================================
# Savings Bank Account.
#
# ============================================================
# SOURCE PAGES
# ============================================================
# 1. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 9
# 2. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 8
# 3. C:\Users\jyoti singh\Data Science\gen ai\SBI-BANKING\data\SBI - CPCR Booklet (English)_14.07.2025.pdf | Page 32
#
# ----------------------------------------------------------------------
